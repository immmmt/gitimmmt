# %%
import networkx as nx
import matplotlib.pyplot as plt

# 创建一个空的有向图
G = nx.DiGraph()

# 添加节点(朋友)
friends = ['A', 'B', 'C', 'D', 'E']
for friend in friends:
    G.add_node(friend)

# 添加边(朋友之间的关系)
edges = [('A', 'B'), ('A', 'C'), ('B', 'D'), ('C', 'E'), ('D', 'E')]
G.add_edges_from(edges)

# 绘制关系图
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='lightblue', font_size=10, font_weight='bold')
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# 创建一个空的多重图
G = nx.MultiGraph()

# 添加节点(朋友)
friends = ['A', 'B', 'C', 'D', 'E']
for friend in friends:
    G.add_node(friend)

# 添加边(朋友之间的关系)
edges = [('A', 'B'), ('A', 'C'), ('B', 'D'), ('C', 'E'), ('D', 'E'), ('E', 'A')]
G.add_edges_from(edges)

# 绘制关系图
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='lightblue', font_size=10, font_weight='bold')
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# 创建一个空的多重图
G = nx.MultiGraph()

# 添加节点(朋友)
friends = ['100001', '100002', '100003', '100004', '100005', '100006', '100007', '100008']
for friend in friends:
    G.add_node(friend)

# 添加边(朋友之间的关系)
edges = [('100001', '100002'), 
        ('100001', '100003'),
        ('100001', '100004'), 
        ('100002', '100003'), 
        ('100002', '100004'),
        ('100003', '100004'),
        ('100003', '100006'),
        ('100003', '100007'),
        ('100003', '100008'),
        ('100005', '100008'),
        ('100005', '100001'),
        ('100005', '100006')]
G.add_edges_from(edges)

# 绘制关系图
pos = nx.spring_layout(G)
nx.draw(G, pos, 
        with_labels=True, 
        node_color='lightblue', 
        node_size=1000,
        font_size=10, 
        font_weight='bold', )
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# 创建一个空的多重图
G = nx.MultiGraph()

# 添加节点(朋友)
friends = ['100001', '100002', '100003', '100004', '100005']
for friend in friends:
    G.add_node(friend)

# 添加边(朋友之间的关系)
edges = [('100001', '100002'), 
        ('100001', '100003'),
        ('100001', '100004'), 
        ('100002', '100003'), 
        ('100002', '100004'),
        ('100003', '100004'),
        ('100003', '100006'),
        ('100003', '100007'),
        ('100003', '100008'),
        ('100005', '100008'),
        ('100005', '100001'),
        ('100005', '100006')]
G.add_edges_from(edges)

# 绘制关系图
pos = nx.spring_layout(G)
import networkx as nx
import matplotlib.pyplot as plt

# 创建一个空的多重图
G = nx.MultiGraph()

# 添加节点(朋友)
friends = ['100001', '100002', '100003', '100004', '100005']
for friend in friends:
    G.add_node(friend)

# 添加边(朋友之间的关系)
edges = [('100001', '100002'), 
        ('100001', '100003'),
        ('100001', '100004'), 
        ('100002', '100003'), 
        ('100002', '100004'),
        ('100003', '100004'),
        ('100003', '100006'),
        ('100003', '100007'),
        ('100003', '100008'),
        ('100005', '100008'),
        ('100005', '100001'),
        ('100005', '100006')]
G.add_edges_from(edges)

# 绘制关系图
pos = nx.spring_layout(G)
nx.draw(G, pos, 
        with_labels=True, 
        node_color='lightblue', 
        node_size=1000,
        font_size=10, 
        font_weight='bold', )

plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# 创建一个空的多重图
G = nx.MultiGraph()

# 添加节点(朋友)
friends = ['100001', '100002', '100003', '100004', '100005']
for friend in friends:
    G.add_node(friend)

# 添加边(朋友之间的关系)
edges = [('100001', '100002'), 
        ('100001', '100003'),
        ('100001', '100004'), 
        ('100002', '100003'), 
        ('100002', '100004'),
        ('100003', '100004'),
        ('100003', '100006'),
        ('100003', '100007'),
        ('100003', '100008'),
        ('100005', '100008'),
        ('100005', '100001'),
        ('100005', '100006')]
G.add_edges_from(edges)

# 绘制关系图
pos = nx.spring_layout(G)
nx.draw(G, pos, 
        with_labels=True, 
        node_color='lightblue', 
        node_size=1500,
        font_size=10, 
        font_weight='bold', 
        edge_color='yellow')
plt.show()

# %%
import requests
import re

session = requests.Session()
session.get('https://tx.com.cn/space/cs/index.do?cf=hd')
url = 'https://tx.com.cn/im/cs/default.do?page=1&z=0iOcPKxjMk'
res = session.get(url)
res.text
# Out:
# '<?xml version="1.0" encoding="utf-8"?><!DOCTYPE wml PUBLIC "-//WAPFORUM//DTD WML 1.1//EN" "http://www.wapforum.org/DTD/wml_1.1.xml"><wml>\r\n<card title="+我的好友(456456)+tx.com.cn" >\r\n<p align="left">\r\n\r\n我的<a href="/im/commonReceive.do?z=0iOcPKxjMk825">消息</a>|<a href="/notify/index.do?z=0iOcPKxjMk825">通知</a>|<strong>好友</strong><br/>\r\n\r\n\r\n\t\t<strong>+所有好友</strong>(<a href="/im/onlineFriend.do?z=0iOcPKxjMk825">114</a>/291)[<a href="/relate/friendManageNew.do?z=0iOcPKxjMk825">管理</a>.<a href="/relate/wakeFriendManage.do?z=0iOcPKxjMk825">唤回</a>]<br />\r\n1.<a href="/im/talkMode.do?z=0iOcPKxjMk825&amp;friendId=2810&amp;f=1">〆.颜づ</a>[<a href="/shop/gift/proxy.do?z=0iOcPKxjMk873&amp;uid=2810&amp;from=relate">送礼</a>]<img src="http://img.tx.com.cn/img/tx/icon/guoqi2012.gif" alt="爱国" /><a href="/shop/vip/index.do?z=0iOcPKxjMk873"><img src="http://img.tx.com.cn/img/tx/logos/vipfive.gif" alt="" /></a><br/>\r\n2.<a href="/im/talkMode.do?z=0iOcPKxjMk873&amp;friendId=6619&amp;f=1">\u3000
# ...
